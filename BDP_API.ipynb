# %%
import pandas as pd

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"interval":"5min","function":"TIME_SERIES_INTRADAY","symbol":"MSFT","datatype":"json","output_size":"compact"}

headers = {
	"X-RapidAPI-Key": "f90a146cbemsh9bfa6cd1edcf7c2p1eb9ebjsn3762e1c646cf",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'MSFT', '3. Last Refreshed': '2024-01-30 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2024-01-30 19:55:00': {'1. open': '406.5100', '2. high': '407.6500', '3. low': '404.6590', '4. close': '407.2600', '5. volume': '50684'}, '2024-01-30 19:50:00': {'1. open': '406.9000', '2. high': '407.2700', '3. low': '406.1000', '4. close': '406.4800', '5. volume': '17100'}, '2024-01-30 19:45:00': {'1. open': '406.1000', '2. high': '407.2000', '3. low': '406.0000', '4. close': '406.8750', '5. volume': '11365'}, '2024-01-30 19:40:00': {'1. open': '405.6700', '2. high': '406.1000', '3. low': '405.6000', '4. close': '406.1000', '5. volume': '8929'}, '2024-01-30 19:35:00': {'1. open': '405.5000', '2. high': '406.4000', '3. low': '405.2600', '4. close': '405.7000', '5. volume': '12831'}, '2024-01-30 19:30:00': {'1. open': '405.
# ...

# %%
abc = response.json()
# abc_auto = abc['autocomplete']

# %%
abc_ts = abc['Time Series (5min)']
abc_ts
# Out:
# {'2024-01-30 19:55:00': {'1. open': '406.5100',
#   '2. high': '407.6500',
#   '3. low': '404.6590',
#   '4. close': '407.2600',
#   '5. volume': '50684'},
#  '2024-01-30 19:50:00': {'1. open': '406.9000',
#   '2. high': '407.2700',
#   '3. low': '406.1000',
#   '4. close': '406.4800',
#   '5. volume': '17100'},
#  '2024-01-30 19:45:00': {'1. open': '406.1000',
#   '2. high': '407.2000',
#   '3. low': '406.0000',
#   '4. close': '406.8750',
#   '5. volume': '11365'},
#  '2024-01-30 19:40:00': {'1. open': '405.6700',
#   '2. high': '406.1000',
#   '3. low': '405.6000',
#   '4. close': '406.1000',
#   '5. volume': '8929'},
#  '2024-01-30 19:35:00': {'1. open': '405.5000',
#   '2. high': '406.4000',
#   '3. low': '405.2600',
#   '4. close': '405.7000',
#   '5. volume': '12831'},
#  '2024-01-30 19:30:00': {'1. open': '405.6300',
#   '2. high': '405.9300',
#   '3. low': '405.0000',
#   '4. close': '405.3900',
#   '5. volume': '15472'},
#  '2024-01-30 19:25:00': {'1. open': '405.8700',
# ...

# %%
lst = list(abc_ts)
val = []

# %%
for i in abc_ts:
  val.append(abc_ts[i])

# %%
df = pd.DataFrame(val, index = lst)

# %%
df.to_csv('bdp_data.csv')

# %%
df
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2024-01-30 19:55:00  406.5100  407.6500  404.6590  407.2600     50684
# 2024-01-30 19:50:00  406.9000  407.2700  406.1000  406.4800     17100
# 2024-01-30 19:45:00  406.1000  407.2000  406.0000  406.8750     11365
# 2024-01-30 19:40:00  405.6700  406.1000  405.6000  406.1000      8929
# 2024-01-30 19:35:00  405.5000  406.4000  405.2600  405.7000     12831
# ...                       ...       ...       ...       ...       ...
# 2024-01-30 12:00:00  409.6700  409.8300  409.5700  409.5800    186527
# 2024-01-30 11:55:00  409.8630  409.8800  409.5300  409.6600    168416
# 2024-01-30 11:50:00  409.7700  409.9200  409.7200  409.8600    154324
# 2024-01-30 11:45:00  409.7910  409.8800  409.6600  409.7550    165576
# 2024-01-30 11:40:00  410.0650  410.1100  409.7300  409.7700    163599
#
# [100 rows x 5 columns]
# No charts were generated by quickchart
